# %% [markdown]
# <a href="https://colab.research.google.com/github/aboutdouglas/Pandas_Numpy/blob/main/Numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # NumPy
#
# *   Ela é a "base" para o Pandas
#
#
# *   Numerical Python
# 1. Biblioteca de computação numérica
# 2. Otimizada para cálculos pesados
#
# > https://numpy.org/
#
#
# *  No NumPy vamos trabalhar com **arrays**, que são mais rápidos e mais performáticos que listas.

# %%
# Importar o numpy
import numpy as np

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # A importância do NumPy
#
# Vamos supor que temos a venda e comissão (em percentual) de 5 vendedores e queremos saber qual vai ser o salário de cada um deles.

# %%
# Venda e comissão
venda_valor = [150000, 230000, 82000, 143000, 184000]
comissao = [5, 8, 8, 5, 12]

# %%
# Ao tentar fazer essa operação com listas, teremos um erro
venda_valor*(comissao/100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-9550dd5971bb> in <module>()
#       1 # Ao tentar fazer essa operação com listas, teremos um erro
# ----> 2 venda_valor*(comissao/100)
#
# TypeError: unsupported operand type(s) for /: 'list' and 'int'

# %% [markdown]
# # Transformar uma lista em um array
#
# meu_array = np.array(minha_lista)

# %%
# Transformando em um array
venda_valor = np.array(venda_valor)
comissao = np.array(comissao)

# %%
# Agora vamos conseguir fazer sendo um array
venda_valor*(comissao/100)
# Out:
# array([ 7500., 18400.,  6560.,  7150., 22080.])

# %% [markdown]
# # Dimensões de um array

# %% [markdown]
# meu_array.shape

# %%
venda_valor.dtype
# Out:
# dtype('int64')

# %%
venda_valor.shape
# Out:
# (5,)

# %% [markdown]
# **Todos os dados de um array vão ter o mesmo tipo**

# %% [markdown]
# Para saber o tipo dos dados, podemos fazer:
# meu_array.dtype

# %%
venda_valor.dtype
# Out:
# dtype('int64')

# %% [markdown]
# **Se tiver dados de diferentes tipos, ele converte para o mesmo tipo**

# %%
tipos_dados = np.array([1, 2, 3, 4, 5])
tipos_dados.dtype
# Out:
# dtype('int64')

# %%
tipos_dados = np.array([1, 2, 3, 4, 5.0])
print(tipos_dados.dtype)
print(tipos_dados)
# Out:
# float64
# [1. 2. 3. 4. 5.]

# %%
tipos_dados = np.array([1, 2, 3, '4', 5])
print(tipos_dados.dtype)
print(tipos_dados)
# Out:
# <U21
# ['1' '2' '3' '4' '5']

# %% [markdown]
# **O array de uma dimensão é o que chamamos de vetor e de duas dimensões de matriz**

# %%
dados_venda = np.array([[1500000, 230000, 82000, 143000, 184000], [5, 8, 8, 5, 12]])

# %%
print(dados_venda)
# Out:
# [[1500000  230000   82000  143000  184000]
#  [      5       8       8       5      12]]

# %%
dados_venda.shape
# Out:
# (2, 5)

# %%
dados_venda.dtype
# Out:
# dtype('int64')

# %%
dados_venda = np.array([['Lucas', 'Bia', 'Jean', 'Gabi', 'Pedro'],[150000, 230000, 82000, 143000, 184000]])
print(dados_venda)
# Out:
# [['Lucas' 'Bia' 'Jean' 'Gabi' 'Pedro']
#  ['150000' '230000' '82000' '143000' '184000']]

# %%
dados_venda.dtype
# Out:
# dtype('<U21')

# %% [markdown]
# Podemos buscar elementos em um **array**

# %%
dados_venda
# Out:
# array([['Lucas', 'Bia', 'Jean', 'Gabi', 'Pedro'],
#        ['150000', '230000', '82000', '143000', '184000']], dtype='<U21')

# %%
# Buscando a primeira linha (lembrando que o python começa com 0)
dados_venda[0]
# Out:
# array(['Lucas', 'Bia', 'Jean', 'Gabi', 'Pedro'], dtype='<U21')

# %%
# Buscando na primeira linha, a segunda coluna
dados_venda[0][1]
# Out:
# 'Bia'

# %%
# Buscando na segunda linha, a terceira coluna
dados_venda[1][2]
# Out:
# '82000'

# %% [markdown]
# **Também podemos mostrar as informações estatísticas de um array**

# %%
# Mostrando as informações estatísticas dessa matriz
dados_venda = np.array([[150000, 230000, 82000, 143000, 184000], [5, 8, 8, 5, 12]])

# %% [markdown]
# **Média do array:**
#
# np.mean(meu_array)

# %%
# Média da primeira linha
np.mean(dados_venda[0])
# Out:
# 157800.0

# %%
# Média da segunda linha
np.mean(dados_venda[1])
# Out:
# 7.6

# %% [markdown]
# **Mediana:**
#
# np.median(meu_array)

# %%
# Mediana da primeira linha
np.median(dados_venda[0])
# Out:
# 150000.0

# %% [markdown]
# **Desvio Padrão:**
#
# np.std(meu_array)

# %%
# Desvio padrão da primeira linha
np.std(dados_venda[0])
# Out:
# 48836.05225650411

# %% [markdown]
# **E realizar operações aritméticas, agregação, comparação, mínimo e máximo, etc**

# %%
# Considerando esses 2 arrays
array1 = np.array([1, 2, 3, 4, 5])
array2 = np.array([7, 8, 9, 10, 11])

# %%
# Soma
array1 + array2
# Out:
# array([ 8, 10, 12, 14, 16])

# %%
# Multiplicação por um valor
array1 * 2
# Out:
# array([ 2,  4,  6,  8, 10])

# %%
# Multiplicação de arrays
array1 * array2
# Out:
# array([ 7, 16, 27, 40, 55])

# %%
# Potência
np.power(array2, array1)
# Out:
# array([     7,     64,    729,  10000, 161051])

# %%
# Soma dos valores da primeira linha
np.sum(array1)
# Out:
# 15

# %%
# Soma acumulada dos valores da primeira linha
np.cumsum(array1)
# Out:
# array([ 1,  3,  6, 10, 15])

# %%
# Valor mínimo
array1.min()
# Out:
# 1

# %%
# Valor máximo
array1.max()
# Out:
# 5

# %% [markdown]
# # Mais sobre o Numpy
#
#
# *   Também podemos usar o NumPy para criar arrays de valores constantes, criar tipos específicos de matrizes (como matriz identidade), fazer produto matricial, transposta, etc.
